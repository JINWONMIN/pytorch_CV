# %%
# !python /content/drive/MyDrive/inception_v1/train.py
# Out:
# Files already downloaded and verified
# image shape of a random sample image : (3, 32, 32)
#
# Training set: 45000 images
# Validation set: 5000 images
# [For Epoch 1/15]: train-loss = 2.41948 | train-acc = 0.446 | val-loss = 2.15649 | val-acc = 0.533
# [For Epoch 2/15]: train-loss = 2.37728 | train-acc = 0.463 | val-loss = 1.92671 | val-acc = 0.552
# [For Epoch 3/15]: train-loss = 2.41571 | train-acc = 0.448 | val-loss = 2.15281 | val-acc = 0.516
# [For Epoch 4/15]: train-loss = 2.38784 | train-acc = 0.460 | val-loss = 2.21739 | val-acc = 0.504
# [For Epoch 5/15]: train-loss = 2.40477 | train-acc = 0.456 | val-loss = 2.29666 | val-acc = 0.502
# [For Epoch 6/15]: train-loss = 2.38719 | train-acc = 0.455 | val-loss = 2.04934 | val-acc = 0.506
# [For Epoch 7/15]: train-loss = 2.40638 | train-acc = 0.455 | val-loss = 2.03069 | val-acc = 0.548
# [For Epoch 8/15]: train-loss = 2.39207 | train-acc = 0.459 | val-loss = 2.34906 | val-acc = 0.489
# ...
